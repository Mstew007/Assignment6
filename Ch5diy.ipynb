# %% [markdown]
# <a href="https://colab.research.google.com/github/Mstew007/Assignment6/blob/main/Ch5diy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#example from textbook
car = 'Lamborghini'
print("Is car == 'Lamborghini'? I predict True.")
print(car == 'Lamobrghini')
print("\nIs car == 'Honda'? I predict False.")
print(car == 'Honda')
#5.1
car="bmw"
if car=="bmw" :
    print("\ni predict True")
else :
    print("false")

car="volkswagen"
if car=="audi" :
    print("i predict True")
else :
    print("false")

car="Honda"
if car=="Honda" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="bmw" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="bmw" :
    print("i predict True")
else :
    print("false")

car="Ferrari"
if car=="Ferrari" :
    print("i predict True")
else :
    print("false")

car="Bugatti"
if car=="bmw" :
    print("i predict True")
else :
    print("false\n")

#5.3 this is the same as there is no output
alien_color = 'green'

if alien_color == 'green':
    print("You earned 5 points!\n")

#5.5
alien_color = 'green'

if alien_color == 'green':
    print("You earned 5 points!\n")

alien_color = 'yellow'

if alien_color == 'green':
    print("You earned 5 points!")
else:
    print("You earned 10 points!\n")

alien_color = 'red'

if alien_color == 'green':
    print("You earned 5 points!")
elif alien_color == 'yellow':
    print("You earned 10 points!")
else:
    print("You earned 15 points!\n")

#5.6
age = 36

if age < 2:
    print("You are a baby")
elif age < 4:
    print("You are a toddler")
elif age < 13:
    print("You are a kid")
elif age < 20:
    print("You are a teenager")
elif age < 65:
    print("You are an adult\n")
else:
    print("You are an elder\n")

#5.7
favorite_fruits = ['apples', 'bananas', 'oranges']

if 'bananas' in favorite_fruits:
    print("I like bananas")
if 'apples' in favorite_fruits:
    print("I like apples")
if 'blueberries' in favorite_fruits:
    print("I like blueberries")
if 'kiwis' in favorite_fruits:
    print("I like kiwis")
if 'oranges' in favorite_fruits:
    print("I like oranges\n")

#5.8
usernames = ['matt', 'joe', 'jack', 'greg', 'admin']

for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?\n")
    else:
        print("Hello " + username + ", thank you for logging in again!\n")

#5.9
usernames = []

if usernames:
    for username in usernames:
        if username == 'admin':
            print("Hello admin, would you like to see a status report?")
        else:
            print("Hello " + username + ", thank you for logging in again!")
else:
    print("We need to find some users!\n")

#5.10
current_users = ['matt', 'joe', 'jack', 'greg', 'admin']
new_users = ['joe', 'ava', 'krista', 'tom', 'matt']

current_users_lower = [user.lower() for user in current_users]

for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print("Sorry " + new_user + ", that name is already taken.\n")
    else:
        print("Awesome, " + new_user + " is still available.\n")

#5.11
numbers = list(range(1,10))

for number in numbers:
    if number == 1:
        print("1st")
    elif number == 2:
        print("2nd")
    elif number == 3:
        print("3rd")
    else:
        print(str(number) + "th")
# Out:
# Is car == 'Lamborghini'? I predict True.
# False
#
# Is car == 'Honda'? I predict False.
# False
#
# i predict True
# false
# i predict True
# false
# false
# i predict True
# false
#
# You earned 5 points!
#
# You earned 5 points!
#
# You earned 10 points!
#
# You earned 15 points!
#
# You are an adult
#
# I like bananas
# I like apples
# I like oranges
#
# Hello matt, thank you for logging in again!
#
# Hello joe, thank you for logging in again!
#
# Hello jack, thank you for logging in again!
#
# Hello greg, thank you for logging in again!
#
# Hello admin, would you like to see a status report?
#
# We need to find some users!
#
# Sorry joe, that name is already taken.
#
# Awesome, ava is still available.
#
# Awesome, krista is still available.
#
# Awesome, tom is still available.
#
# Sorry matt, that name is already taken.
#
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
